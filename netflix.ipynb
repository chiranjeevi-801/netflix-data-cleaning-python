# %% [markdown]
# ### import libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd
df=pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### check  missing values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Remove Duplicate Rows

# %%
df=df.drop_duplicates()
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ## Handle missing values

# %% [markdown]
# ###  Fill missing director

# %%
df['director']=df['director'].fillna('unknown')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Fill missing cast

# %%
df['cast']=df['cast'].fillna("Not Available")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                      Not Available            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Fill missing country

# %%
df['country']=df['country'].fillna("null")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           null
# 3                                      Not Available           null
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Fill missing rating

# %%
df['rating']=df['rating'].fillna("Not Rated")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           null
# 3                                      Not Available           null
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Drop rows where date_added is missing

# %%
df=df.dropna(subset=['date_added'])
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                        unknown
# 2                Julien Leclercq
# 3                        unknown
# 4                        unknown
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                      Not Available
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                      Not Available
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                               null  September 24, 2021
# 3                                               null  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                               null  September 24, 2021
# 6                                               null  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...

# %% [markdown]
# ## Convert Date Column

# %%
df['date_added'] = df['date_added'].str.strip()
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           null
# 3                                      Not Available           null
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ###  Extract year and Month Added

# %%
df['date_added'] = df['date_added'].str.strip()
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           null
# 3                                      Not Available           null
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  year_added  month_added
# 0  As her father nears the end of his life, filmm...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 2  To protect his family from a powerful drug lor...        2021            9
# 3  Feuds, flirtations and toilet talk go down amo...        2021            9
# 4  In a city of coaching centers known to train I...        2021            9

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# year_added               int32
# month_added              int32
# dtype: object

# %%
df['year_added'].value_counts().sort_index()
# Out:
# year_added
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      24
# 2015      82
# 2016     429
# 2017    1188
# 2018    1649
# 2019    2016
# 2020    1879
# 2021    1498
# Name: count, dtype: int64

# %% [markdown]
# ## Clean Duration column
#
# The duration column contains:
#
# 90 min
#
# 1 Season
#
# 2 Seasons
#
# Split into number and unit.

# %%
df[['duration_number','duration_unit']]=df['duration'].str.split(' ',expand=True)

# %% [markdown]
# Check first few rows

# %%
df[['duration','duration_number','duration_unit']].head()
# Out:
#     duration duration_number duration_unit
# 0     90 min              90           min
# 1  2 Seasons               2       Seasons
# 2   1 Season               1        Season
# 3   1 Season               1        Season
# 4  2 Seasons               2       Seasons

# %% [markdown]
# Check last rows

# %%
df[['duration','duration_number','duration_unit']].tail()
# Out:
#        duration duration_number duration_unit
# 8802    158 min             158           min
# 8803  2 Seasons               2       Seasons
# 8804     88 min              88           min
# 8805     88 min              88           min
# 8806    111 min             111           min

# %% [markdown]
# Check column data types

# %%
df[['duration_number','duration_unit']].dtypes
# Out:
# duration_number    object
# duration_unit      object
# dtype: object

# %% [markdown]
# check the unique values

# %%
df['duration_unit'].unique()
# Out:
# array(['min', 'Seasons', 'Season', nan], dtype=object)

# %%
# split duration
df[['duration_number','duration_unit']]=df['duration'].str.split(' ',expand=True)

# convert to number
df['duration_number']=pd.to_numeric(df['duration_number'],errors='coerce')

# group analyisis
df.groupby('duration_unit')['duration_number'].mean()
# Out:
# duration_unit
# Season      1.000000
# Seasons     3.294387
# min        99.577187
# Name: duration_number, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8797 entries, 0 to 8806
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8797 non-null   object
#  1   type             8797 non-null   object
#  2   title            8797 non-null   object
#  3   director         8797 non-null   object
#  4   cast             8797 non-null   object
#  5   country          8797 non-null   object
#  6   date_added       8797 non-null   datetime64[ns]
#  7   release_year     8797 non-null   int64
#  8   rating           8797 non-null   object
#  9   duration         8794 non-null   object
#  10  listed_in        8797 non-null   object
#  11  description      8797 non-null   object
#  12  year_added       8797 non-null   int32
#  13  month_added      8797 non-null   int32
#  14  duration_number  8794 non-null   float64
#  15  duration_unit    8794 non-null   object
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Clean Genre Column
#
# Genres are separated by commas.
#
# Convert to list:

# %%
df['listed_in']=df['listed_in'].str.split(',')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           null
# 3                                      Not Available           null
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  listed_in  \
# 0 2021-09-25          2020  PG-13     90 min        NaN
# 1 2021-09-24          2021  TV-MA  2 Seasons        NaN
# 2 2021-09-24          2021  TV-MA   1 Season        NaN
# 3 2021-09-24          2021  TV-MA   1 Season        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons        NaN
#
#                                          description  year_added  month_added  \
# 0  As her father nears the end of his life, filmm...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 2  To protect his family from a powerful drug lor...        2021            9
# 3  Feuds, flirtations and toilet talk go down amo...        2021            9
# 4  In a city of coaching centers known to train I...        2021            9
#
#    duration_number duration_unit
# 0             90.0           min
# 1              2.0       Seasons
# 2              1.0        Season
# 3              1.0        Season
# 4              2.0       Seasons

# %% [markdown]
# ### Clean Country column
#
# Remove extra workspace

# %%
df['country']=df['country'].str.strip()
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           null
# 3                                      Not Available           null
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  listed_in  \
# 0 2021-09-25          2020  PG-13     90 min        NaN
# 1 2021-09-24          2021  TV-MA  2 Seasons        NaN
# 2 2021-09-24          2021  TV-MA   1 Season        NaN
# 3 2021-09-24          2021  TV-MA   1 Season        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons        NaN
#
#                                          description  year_added  month_added  \
# 0  As her father nears the end of his life, filmm...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 2  To protect his family from a powerful drug lor...        2021            9
# 3  Feuds, flirtations and toilet talk go down amo...        2021            9
# 4  In a city of coaching centers known to train I...        2021            9
#
#    duration_number duration_unit
# 0             90.0           min
# 1              2.0       Seasons
# 2              1.0        Season
# 3              1.0        Season
# 4              2.0       Seasons

# %% [markdown]
# ### Standardlize Text
# Convert to lowercase (optional but useful).

# %%
df['title']=df['title'].str.lower()
df['director']=df['director'].str.lower()
df['country']=df['country'].str.lower()

# %% [markdown]
# Reset Index

# %%
df=df.reset_index(drop=True)

# %% [markdown]
# ### Check Cleaned Dataset

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   dick johnson is dead  kirsten johnson
# 1      s2  TV Show          blood & water          unknown
# 2      s3  TV Show              ganglands  julien leclercq
# 3      s4  TV Show  jailbirds new orleans          unknown
# 4      s5  TV Show           kota factory          unknown
#
#                                                 cast        country  \
# 0                                      Not Available  united states
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   south africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           null
# 3                                      Not Available           null
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          india
#
#   date_added  release_year rating   duration  listed_in  \
# 0 2021-09-25          2020  PG-13     90 min        NaN
# 1 2021-09-24          2021  TV-MA  2 Seasons        NaN
# 2 2021-09-24          2021  TV-MA   1 Season        NaN
# 3 2021-09-24          2021  TV-MA   1 Season        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons        NaN
#
#                                          description  year_added  month_added  \
# 0  As her father nears the end of his life, filmm...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 2  To protect his family from a powerful drug lor...        2021            9
# 3  Feuds, flirtations and toilet talk go down amo...        2021            9
# 4  In a city of coaching centers known to train I...        2021            9
#
#    duration_number duration_unit
# 0             90.0           min
# 1              2.0       Seasons
# 2              1.0        Season
# 3              1.0        Season
# 4              2.0       Seasons

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8797 entries, 0 to 8796
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8797 non-null   object
#  1   type             8797 non-null   object
#  2   title            8797 non-null   object
#  3   director         8797 non-null   object
#  4   cast             8797 non-null   object
#  5   country          8797 non-null   object
#  6   date_added       8797 non-null   datetime64[ns]
#  7   release_year     8797 non-null   int64
#  8   rating           8797 non-null   object
#  9   duration         8794 non-null   object
#  10  listed_in        0 non-null      float64
#  11  description      8797 non-null   object
#  12  year_added       8797 non-null   int32
#  13  month_added      8797 non-null   int32
#  14  duration_number  8794 non-null   float64
#  15  duration_unit    8794 non-null   object
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director              0
# cast                  0
# country               0
# date_added            0
# release_year          0
# rating                0
# duration              3
# listed_in          8797
# description           0
# year_added            0
# month_added           0
# duration_number       3
# duration_unit         3
# dtype: int64

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8792   s8803    Movie       zodiac    david fincher
# 8793   s8804  TV Show  zombie dumb          unknown
# 8794   s8805    Movie   zombieland  ruben fleischer
# 8795   s8806    Movie         zoom     peter hewitt
# 8796   s8807    Movie       zubaan      mozez singh
#
#                                                    cast        country  \
# 8792  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  united states
# 8793                                      Not Available           null
# 8794  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  united states
# 8795  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  united states
# 8796  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          india
#
#      date_added  release_year rating   duration  listed_in  \
# 8792 2019-11-20          2007      R    158 min        NaN
# 8793 2019-07-01          2018  TV-Y7  2 Seasons        NaN
# 8794 2019-11-01          2009      R     88 min        NaN
# 8795 2020-01-11          2006     PG     88 min        NaN
# 8796 2019-03-02          2015  TV-14    111 min        NaN
#
#                                             description  year_added  \
# 8792  A political cartoonist, a crime reporter and a...        2019
# 8793  While living alone in a spooky town, a young g...        2019
# 8794  Looking to survive in a world taken over by zo...        2019
# 8795  Dragged from civilian life, a former superhero...        2020
# 8796  A scrappy but poor boy worms his way into a ty...        2019
#
#       month_added  duration_number duration_unit
# 8792           11            158.0           min
# 8793            7              2.0       Seasons
# 8794           11             88.0           min
# 8795            1             88.0           min
# 8796            3            111.0           min

# %% [markdown]
# ### Save Cleaned Dateset

# %%
df.to_csv("cleaned_netflix_dataset.csv",index=False)

# %% [markdown]
# ### After Cleaning You Can Do Analysis
#
# Movies vs TV Shows

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2666
# Name: count, dtype: int64

# %% [markdown]
# Top Countries

# %%
df['country'].value_counts().head(10)
# Out:
# country
# united states     2812
# india              972
# null               830
# united kingdom     418
# japan              244
# south korea        199
# canada             181
# spain              145
# france             124
# mexico             110
# Name: count, dtype: int64

# %% [markdown]
# Content added per year

# %%
df['year_added'].value_counts()
# Out:
# year_added
# 2019    2016
# 2020    1879
# 2018    1649
# 2021    1498
# 2017    1188
# 2016     429
# 2015      82
# 2014      24
# 2011      13
# 2013      11
# 2012       3
# 2009       2
# 2008       2
# 2010       1
# Name: count, dtype: int64

# %% [markdown]
# # next part

# %% [markdown]
# ### Basic Information

# %%
print("shape of dataset:",df.shape)

print("\nColumns:")
print(df.columns)

df.info()
# Out:
# shape of dataset: (8797, 16)
#
# Columns:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'year_added', 'month_added', 'duration_number', 'duration_unit'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8797 entries, 0 to 8796
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8797 non-null   object
#  1   type             8797 non-null   object
#  2   title            8797 non-null   object
#  3   director         8797 non-null   object
#  4   cast             8797 non-null   object
#  5   country          8797 non-null   object
#  6   date_added       8797 non-null   datetime64[ns]
#  7   release_year     8797 non-null   int64
#  8   rating           8797 non-null   object
#  9   duration         8794 non-null   object
#  10  listed_in        0 non-null      float64
#  11  description      8797 non-null   object
#  12  year_added       8797 non-null   int32
#  13  month_added      8797 non-null   int32
#  14  duration_number  8794 non-null   float64
#  15  duration_unit    8794 non-null   object
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Check Missing Values

# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv")

missing_values=df.isnull().sum()
print("missing_values:\n",missing_values)
# Out:
# missing_values:
#  show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Visualize missing values:

# %%
import pandas as pd
import matplotlib.pyplot as plt

missing_values = df.isnull().sum()

missing_values.plot(kind='bar')

plt.title("Missing Values in Dataset")
plt.xlabel("Columns")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ### Remove Dupilcate Rows

# %%
duplicates=df.duplicated().sum()
print("Duplicate rows:",duplicates)

df=df.drop_duplicates()
# Out:
# Duplicate rows: 0

# %% [markdown]
# ### Clean Text cloumns
#
# Remove extra spaces

# %%
df['country']=df['country'].str.strip()
df['director']=df['director'].str.strip()
df['cast']=df['cast'].str.strip()

# %% [markdown]
# Convert to lowercase:

# %%
df['title'] = df['title'].str.lower()
df['director'] = df['director'].str.lower()
df['country'] = df['country'].str.lower()

# %% [markdown]
# ### Clean Genre Column
#
# Convert genres into list:

# %%
df['listed_in'] = df['listed_in'].str.split(',')

# %% [markdown]
# ### Reset index

# %%
df=df.reset_index(drop=True)

# %% [markdown]
# ### Final Dataset Check

# %%
print(df.info())

print("\nRemaining Missing Values:")
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None
#
# Remaining Missing Values:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Visualization After Cleaning
# Movies vs TV Shows

# %%
df['type'].value_counts().plot(kind='bar')

plt.title("Movies vs TV Shows on Netflix")
plt.xlabel("Type")
plt.ylabel("Count")

plt.show()
